# %% [markdown]
# tensorflow 1 版本。

# %%
import os
import math
import numpy as np
import tensorflow as tf
from PIL import Image
import time

# 之前vgg模型，RGB通道的3个均值，我们输入图像时，需要减去这三个均值，这三个均值是写在vgg16 net的代码中的
VGG_MEAN = [103.939, 116.779, 123.68]

class VGGNet:
    """Builds VGG-16 net structure,
       load parameters from pre-train models.
    """
    def __init__(self, data_dict):    # 把权重拿进来
        self.data_dict = data_dict
    
    def get_conv_filter(self, name):  # 拿卷积层的参数。 name可能是conv1_2
        #self.data_dict[name][0]是w参数，[1]是偏置
        return tf.constant(self.data_dict[name][0], name='conv')
    
    def get_fc_weight(self, name):    # 全连接层参数，和上面类似
        return tf.constant(self.data_dict[name][0], name='fc')
    
    def get_bias(self, name):         # 偏置参数
        return tf.constant(self.data_dict[name][1], name='bias')
    
    def conv_layer(self, x, name):
        """创建卷积层"""
        with tf.name_scope(name):
            conv_w = self.get_conv_filter(name)
            conv_b = self.get_bias(name)
            # 第二个参数是卷积核，第三个参数是步长，上面第三个参数是各个维度的stide
            h = tf.nn.conv2d(x, conv_w, [1,1,1,1], padding='SAME')  # 这个api比layers更基础
            h = tf.nn.bias_add(h, conv_b)
            h = tf.nn.relu(h)
            return h
    
    def pooling_layer(self, x, name):
        """Builds pooling layer."""
        return tf.nn.max_pool(x,
                              ksize = [1,2,2,1],  # 样本数，宽，高，通道数
                              strides = [1,2,2,1],
                              padding = 'SAME',
                              name = name)
    
    def fc_layer(self, x, name, activation=tf.nn.relu):
        """Builds fully-connected layer."""
        with tf.name_scope(name):
            fc_w = self.get_fc_weight(name)
            fc_b = self.get_bias(name)
            h = tf.matmul(x, fc_w)   # xw
            h = tf.nn.bias_add(h, fc_b)
            if activation is None:  # 显式传一个 None 进来，才会走这里
                return h
            else:
                return activation(h)
    
    def flatten_layer(self, x, name):  # 通过展平将卷积层展平后给全连接
        """Builds flatten layer."""
        with tf.name_scope(name):
            # [batch_size, image_width, image_height, channel]  4维张量含义
            x_shape = x.get_shape().as_list()
            dim = 1
            for d in x_shape[1:]: # 把后3个维度相乘
                dim *= d
            x = tf.reshape(x, [-1, dim])  #-1就会变为batch_size
            return x
    

    def build(self, x_rgb):
        """Build VGG16 network structure.
        Parameters:
        - x_rgb: [1, 224, 224, 3]  #这个设置是vgg_net的设置
        """
        
        start_time = time.time()
        print('building model ...')
        
        # 模仿原有的模型，都减去了 VGG_MEAN
        r, g, b = tf.split(x_rgb, [1,1,1], axis=3)  #切分为3份，每份只有一个通道，从轴3切割
        x_bgr = tf.concat(
            [b - VGG_MEAN[0],
             g - VGG_MEAN[1],
             r - VGG_MEAN[2]],
            axis = 3)  # 每个通道减去均值后再次合并
        
        assert x_bgr.get_shape().as_list()[1:] == [224, 224, 3]  #做一个断言，防止后面出错
        #这里是第一组
        self.conv1_1 = self.conv_layer(x_bgr, 'conv1_1')
        self.conv1_2 = self.conv_layer(self.conv1_1, 'conv1_2')
        self.pool1 = self.pooling_layer(self.conv1_2, 'pool1')
        #第二组
        self.conv2_1 = self.conv_layer(self.pool1, 'conv2_1')
        self.conv2_2 = self.conv_layer(self.conv2_1, 'conv2_2')
        self.pool2 = self.pooling_layer(self.conv2_2, 'pool2')
        
        self.conv3_1 = self.conv_layer(self.pool2, 'conv3_1')
        self.conv3_2 = self.conv_layer(self.conv3_1, 'conv3_2')
        self.conv3_3 = self.conv_layer(self.conv3_2, 'conv3_3')
        self.pool3 = self.pooling_layer(self.conv3_3, 'pool3')
        
        self.conv4_1 = self.conv_layer(self.pool3, 'conv4_1')
        self.conv4_2 = self.conv_layer(self.conv4_1, 'conv4_2')
        self.conv4_3 = self.conv_layer(self.conv4_2, 'conv4_3')
        self.pool4 = self.pooling_layer(self.conv4_3, 'pool4')
        
        self.conv5_1 = self.conv_layer(self.pool4, 'conv5_1')
        self.conv5_2 = self.conv_layer(self.conv5_1, 'conv5_2')
        self.conv5_3 = self.conv_layer(self.conv5_2, 'conv5_3')
        self.pool5 = self.pooling_layer(self.conv5_3, 'pool5')
        
        # 大部分时间都花费在下面的全连接层上,可以注释掉看看
        # 全连接层参数量非常大
        self.flatten5 = self.flatten_layer(self.pool5, 'flatten')
        self.fc6 = self.fc_layer(self.flatten5, 'fc6')
        self.fc7 = self.fc_layer(self.fc6, 'fc7')
        self.fc8 = self.fc_layer(self.fc7, 'fc8', activation=None) # fc8不加激活函数是因为最后我们要进行softmax
        self.prob = tf.nn.softmax(self.fc8, name='prob')
        
        
        print('building model finished: %4ds' % (time.time() - start_time))  #模型构建好再次打印时间
# Out:
# /home/luke/.virtualenvs/tf1.8/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/luke/.virtualenvs/tf1.8/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/luke/.virtualenvs/tf1.8/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/luke/.virtualenvs/tf1.8/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/luke/.virtualenvs/tf1.8/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/luke/.virtualenvs/tf1.8/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 下面代码只是测试一下模型的构建时间
vgg16_npy_path = 'vgg16.npy'
data_dict =np.load('vgg16.npy', encoding='latin1',allow_pickle=True).item()
vgg16_for_result = VGGNet( data_dict)
content = tf.placeholder(tf.float32,shape=[1,224,224,3])
vgg16_for_result.build(content)
# Out:
# building model ...
# building model finished:    6s

# %%
vgg16_npy_path = 'vgg16.npy'
content_img_path = 'gugong.jpg'  #内容图像路径，这个可以修改
style_img_path = 'xingkong.jpeg'  #风格图像路径，这个也可以修改

num_steps = 100  #训练多少步
learning_rate = 10

lambda_c = 0.1   #内容损失的系数，如果设置为0，就是只用风格特征重建图片
lambda_s = 500   #风格损失系数，通过最终的打印就可以明白为什么，如果为零，就是只有内容特征重建图片

output_dir = './run_style_transfer'  #输出文件夹

if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# %%
# 对图像进行初始化(划掉)
# 产生一个白噪声图像（猜测）
# shape表示生成张量的维度，mean是均值，stddev是标准差。这个函数产生正太分布，均值和标准差自己设定
def initial_result(shape, mean, stddev):
    initial = tf.truncated_normal(shape, mean = mean, stddev = stddev)
    return tf.Variable(initial)

#读取图像数据
def read_img(img_name):
    img = Image.open(img_name)
    np_img = np.array(img) # (224, 224, 3)
    np_img = np.asarray([np_img], dtype=np.int32) # 转维度为(1, 224, 224, 3)
    return np_img

def gram_matrix(x):
    """Calulates gram matrix
    Args:
    - x: feaures extracted from VGG Net. shape: [1, width, height, ch]
    """
    b, w, h, ch = x.get_shape().as_list()  #获取各个维度的值, b = batch size, w = width, h = height, ch = channel
    features = tf.reshape(x, [b, h*w, ch]) # [ch, ch] -> (i, j)  #因为w和h维度像素点特点一致
    # [h*w, ch] matrix -> [ch, h*w] * [h*w, ch] -> [ch, ch]  
    # 计算任意两列的相似度，通过矩阵乘法即可，adjoint_a是把其中一个features进行转置
    #为了防止最终的数比较大，我们除以一个常量，矩阵维度的乘积
    # 参考我在 zotero 中的笔记
    gram = tf.matmul(features, features, adjoint_a=True) / tf.constant(ch * w * h, tf.float32)
    return gram
    

result = initial_result((1, 224, 224, 3), 127.5, 20) # 对弱类型语言彻底怒了😡

content_val = read_img(content_img_path)
style_val = read_img(style_img_path)

content = tf.placeholder(tf.float32, shape=[1, 224, 224, 3])  #这是1.0版本需要的
style = tf.placeholder(tf.float32, shape=[1, 224, 224, 3])

data_dict = np.load(vgg16_npy_path, encoding='latin1',allow_pickle=True).item()

# 创建 3 个 vggnet
vgg_for_content = VGGNet(data_dict)
vgg_for_style = VGGNet(data_dict)
vgg_for_result = VGGNet(data_dict)

vgg_for_content.build(content)  # content是它的输入
vgg_for_style.build(style)
vgg_for_result.build(result)    # 白噪声图片？
#下面的层次也是超参数，多层效果比较好
#可以加其他层特征来尝试，感受不同的效果
content_features = [
    vgg_for_content.conv1_2,
    # vgg_for_content.conv2_2,
    # vgg_for_content.conv3_3,
    # vgg_for_content.conv4_3,
    # vgg_for_content.conv5_3
]

#结果一定要和内容的层数保持一致
result_content_features = [
    vgg_for_result.conv1_2,   # 白噪声的那个 vgg？
    # vgg_for_result.conv2_2,
    # vgg_for_result.conv3_3,
    # vgg_for_result.conv4_3,
    # vgg_for_result.conv5_3
]

# 也给风格特征初始化层次。越是高层越是可以提取到风格
# feature_size, [1, width, height, channel]
style_features = [
    # vgg_for_style.conv1_2,
    # vgg_for_style.conv2_2,
    # vgg_for_style.conv3_3,
    vgg_for_style.conv4_3,
    # vgg_for_style.conv5_3
]

#风格图像的gram矩阵，gram矩阵是两两通道之间的相似度
style_gram = [gram_matrix(feature) for feature in style_features]
#给结果图像提取特征，和风格特征图像的层次必须一致
result_style_features = [
    # vgg_for_result.conv1_2,
    # vgg_for_result.conv2_2,
    # vgg_for_result.conv3_3,
    vgg_for_result.conv4_3,     # 白噪声的 vgg？
    # vgg_for_result.conv5_3
]

#结果图像的gram矩阵
result_style_gram = \
    [gram_matrix(feature) for feature in result_style_features]

content_loss = tf.zeros(1, tf.float32)
# zip: [1, 2], [3, 4], zip([1,2], [3,4]) -> [(1, 3), (2, 4)]
# shape: [1, width, height, channel]
# 内容损失。因为是多层的，所以需要对每一层去计算损失，加起来.
for c, c_ in zip(content_features, result_content_features):
    content_loss += tf.reduce_mean((c - c_) ** 2, [1, 2, 3])

#风格损失是gram矩阵的损失
style_loss = tf.zeros(1, tf.float32)
for s, s_ in zip(style_gram, result_style_gram):
    style_loss += tf.reduce_mean((s - s_) ** 2, [1, 2])

#最终的损失是内容的损失，是内容损失和风格损失的加权
loss = content_loss * lambda_c + style_loss * lambda_s
train_op = tf.train.AdamOptimizer(learning_rate).minimize(loss)
# Out:
# building model ...
# building model finished:    5s
# building model ...
# building model finished:    3s
# building model ...
# building model finished:    3s
# WARNING:tensorflow:From /home/luke/.virtualenvs/tf1.8/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
init_op = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init_op)
    for step in range(num_steps):#训练步骤
        loss_value, content_loss_value, style_loss_value, _ \
            = sess.run([loss, content_loss, style_loss, train_op],
                     feed_dict = {
                         content: content_val,  #输入内容图像
                         style: style_val, #输入风格图像
                     })
        print('step: %d, loss_value: %8.4f, content_loss: %8.4f, style_loss: %8.4f' 
              % (step+1,
                 loss_value[0],
                 content_loss_value[0],
                 style_loss_value[0]))  #每次训练打印loss，content_loss，style_loss
        result_img_path = os.path.join(
            output_dir, 'result-%05d.jpg' % (step+1)) #每一步都把结果图像存储
        result_val = result.eval(sess)[0]  #本身维度是(1, 224, 224, 3)，[0]就是(224, 224, 3)
        result_val = np.clip(result_val, 0, 255)  # 值拉到0到255，小于0的变为0，大于255的变为255
        img_arr = np.asarray(result_val, np.uint8)
        img = Image.fromarray(img_arr)  #这个可以将某个ndarray变为图像
        img.save(result_img_path)  #保存图像
# Out:
# step: 1, loss_value: 14289.9453, content_loss: 60744.5273, style_loss:  16.4310
# step: 2, loss_value: 11878.9717, content_loss: 46403.2227, style_loss:  14.4773
# step: 3, loss_value: 9006.2031, content_loss: 37620.0820, style_loss:  10.4884
# step: 4, loss_value: 7202.0200, content_loss: 32734.5508, style_loss:   7.8571
# step: 5, loss_value: 7109.9717, content_loss: 29922.8926, style_loss:   8.2354
# step: 6, loss_value: 6395.7783, content_loss: 28762.7324, style_loss:   7.0390
# step: 7, loss_value: 5728.5449, content_loss: 28213.6152, style_loss:   5.8144
# step: 8, loss_value: 5163.8896, content_loss: 28140.9492, style_loss:   4.6996
# step: 9, loss_value: 5034.5366, content_loss: 28193.8008, style_loss:   4.4303
# step: 10, loss_value: 4738.1509, content_loss: 28236.8652, style_loss:   3.8289
# step: 11, loss_value: 4633.3667, content_loss: 28275.2910, style_loss:   3.6117
# step: 12, loss_value: 4418.6318, content_loss: 28271.5977, style_loss:   3.1829
# step: 13, loss_value: 4342.4189, content_loss: 28112.6484, style_loss:   3.0623
# step: 14, loss_value: 4162.4600, content_loss: 27766.3730, style_loss:   2.7716
# step: 15, loss_value: 4064.7939, content_loss: 27301.4648, style_loss:   2.6693
# step: 16, loss_value: 3911.3086, content_loss: 26724.6328, style_loss:   2.4777
# step: 17, loss_value: 3756.8533, content_loss: 26003.0723, style_loss:   2.3131
# step: 18, loss_value: 3623.7695, content_loss: 25176.7910, style_loss:   2.2122
# step: 19, loss_value: 3463.7571, content_loss: 24297.8516, style_loss:   2.0679
# step: 20, loss_value: 3316.1187, content_loss: 23363.1250, style_loss:   1.9596
# step: 21, loss_value: 3178.9351, content_loss: 22375.5645, style_loss:   1.8828
# step: 22, loss_value: 3037.1306, content_loss: 21395.5508, style_loss:   1.7952
# step: 23, loss_value: 2900.8433, content_loss: 20416.0645, style_loss:   1.7185
# step: 24, loss_value: 2777.6917, content_loss: 19464.0156, style_loss:   1.6626
# step: 25, loss_value: 2660.3018, content_loss: 18548.4688, style_loss:   1.6109
# step: 26, loss_value: 2563.9507, content_loss: 17646.8086, style_loss:   1.5985
# step: 27, loss_value: 2472.1030, content_loss: 16833.1777, style_loss:   1.5776
# step: 28, loss_value: 2415.3918, content_loss: 16039.7168, style_loss:   1.6228
# step: 29, loss_value: 2281.2463, content_loss: 15350.1631, style_loss:   1.4925
# step: 30, loss_value: 2177.6255, content_loss: 14677.0820, style_loss:   1.4198
# step: 31, loss_value: 2100.6348, content_loss: 14058.4160, style_loss:   1.3896
# step: 32, loss_value: 2046.8074, content_loss: 13495.7822, style_loss:   1.3945
# step: 33, loss_value: 2018.6270, content_loss: 12952.7266, style_loss:   1.4467
# step: 34, loss_value: 1955.7903, content_loss: 12496.1123, style_loss:   1.4124
# step: 35, loss_value: 1907.0754, content_loss: 12044.4580, style_loss:   1.4053
# step: 36, loss_value: 1800.1202, content_loss: 11667.4248, style_loss:   1.2668
# step: 37, loss_value: 1758.5314, content_loss: 11302.3213, style_loss:   1.2566
# step: 38, loss_value: 1743.4786, content_loss: 10955.5049, style_loss:   1.2959
# step: 39, loss_value: 1713.6243, content_loss: 10658.5586, style_loss:   1.2955
# step: 40, loss_value: 1718.7773, content_loss: 10347.2207, style_loss:   1.3681
# step: 41, loss_value: 1619.6787, content_loss: 10112.8916, style_loss:   1.2168
# step: 42, loss_value: 1593.9960, content_loss: 9869.7568, style_loss:   1.2140
# step: 43, loss_value: 1536.0394, content_loss: 9641.7959, style_loss:   1.1437
# step: 44, loss_value: 1541.2856, content_loss: 9449.7822, style_loss:   1.1926
# step: 45, loss_value: 1540.6877, content_loss: 9246.9131, style_loss:   1.2320
# step: 46, loss_value: 1517.2358, content_loss: 9096.0928, style_loss:   1.2153
# step: 47, loss_value: 1524.8386, content_loss: 8909.5137, style_loss:   1.2678
# step: 48, loss_value: 1429.3975, content_loss: 8778.3604, style_loss:   1.1031
# step: 49, loss_value: 1426.1907, content_loss: 8646.3633, style_loss:   1.1231
# step: 50, loss_value: 1374.1155, content_loss: 8509.5381, style_loss:   1.0463
# step: 51, loss_value: 1394.5084, content_loss: 8386.8330, style_loss:   1.1117
# step: 52, loss_value: 1380.3134, content_loss: 8241.4277, style_loss:   1.1123
# step: 53, loss_value: 1366.2832, content_loss: 8145.3730, style_loss:   1.1035
# step: 54, loss_value: 1376.3137, content_loss: 8012.4434, style_loss:   1.1501
# step: 55, loss_value: 1292.9338, content_loss: 7925.9390, style_loss:   1.0007
# step: 56, loss_value: 1292.6051, content_loss: 7835.1484, style_loss:   1.0182
# step: 57, loss_value: 1264.9866, content_loss: 7735.9067, style_loss:   0.9828
# step: 58, loss_value: 1266.4309, content_loss: 7658.1860, style_loss:   1.0012
# step: 59, loss_value: 1251.5049, content_loss: 7558.2319, style_loss:   0.9914
# step: 60, loss_value: 1258.1086, content_loss: 7487.3867, style_loss:   1.0187
# step: 61, loss_value: 1288.3823, content_loss: 7380.7666, style_loss:   1.1006
# step: 62, loss_value: 1214.5493, content_loss: 7308.5806, style_loss:   0.9674
# step: 63, loss_value: 1213.0659, content_loss: 7223.7979, style_loss:   0.9814
# step: 64, loss_value: 1175.0748, content_loss: 7169.7944, style_loss:   0.9162
# step: 65, loss_value: 1178.6996, content_loss: 7101.8125, style_loss:   0.9370
# step: 66, loss_value: 1144.8796, content_loss: 7024.4722, style_loss:   0.8849
# step: 67, loss_value: 1140.5303, content_loss: 6957.2539, style_loss:   0.8896
# step: 68, loss_value: 1139.6871, content_loss: 6878.0640, style_loss:   0.9038
# step: 69, loss_value: 1126.3406, content_loss: 6819.1479, style_loss:   0.8889
# step: 70, loss_value: 1158.8198, content_loss: 6711.6265, style_loss:   0.9753
# step: 71, loss_value: 1180.7976, content_loss: 6656.4546, style_loss:   1.0303
# step: 72, loss_value: 1272.1353, content_loss: 6571.7671, style_loss:   1.2299
# step: 73, loss_value: 1119.4387, content_loss: 6565.9058, style_loss:   0.9257
# step: 74, loss_value: 1119.5651, content_loss: 6541.2383, style_loss:   0.9309
# step: 75, loss_value: 1138.3264, content_loss: 6520.8633, style_loss:   0.9725
# step: 76, loss_value: 1099.8802, content_loss: 6531.1367, style_loss:   0.8935
# step: 77, loss_value: 1091.0391, content_loss: 6504.7534, style_loss:   0.8811
# step: 78, loss_value: 1080.6888, content_loss: 6462.2690, style_loss:   0.8689
# step: 79, loss_value: 1069.8384, content_loss: 6420.5806, style_loss:   0.8556
# step: 80, loss_value: 1055.9436, content_loss: 6362.4492, style_loss:   0.8394
# step: 81, loss_value: 1048.1600, content_loss: 6308.3047, style_loss:   0.8347
# step: 82, loss_value: 1051.1628, content_loss: 6235.3076, style_loss:   0.8553
# step: 83, loss_value: 1035.9528, content_loss: 6182.2764, style_loss:   0.8355
# step: 84, loss_value: 1055.4065, content_loss: 6092.0005, style_loss:   0.8924
# step: 85, loss_value: 1081.5031, content_loss: 6053.4492, style_loss:   0.9523
# step: 86, loss_value: 1181.7058, content_loss: 5962.9106, style_loss:   1.1708
# step: 87, loss_value: 1091.2107, content_loss: 5963.1191, style_loss:   0.9898
# step: 88, loss_value: 1042.5715, content_loss: 5930.0503, style_loss:   0.8991
# step: 89, loss_value: 1041.2986, content_loss: 5937.6299, style_loss:   0.8951
# step: 90, loss_value: 1039.6674, content_loss: 5948.7920, style_loss:   0.8896
# step: 91, loss_value: 1015.2021, content_loss: 5932.2329, style_loss:   0.8440
# step: 92, loss_value: 1010.1266, content_loss: 5934.4785, style_loss:   0.8334
# step: 93, loss_value: 996.7943, content_loss: 5905.7334, style_loss:   0.8124
# step: 94, loss_value: 989.2694, content_loss: 5866.0728, style_loss:   0.8053
# step: 95, loss_value: 977.4390, content_loss: 5819.7852, style_loss:   0.7909
# step: 96, loss_value: 963.6681, content_loss: 5764.2168, style_loss:   0.7745
# step: 97, loss_value: 954.0481, content_loss: 5716.9565, style_loss:   0.7647
# step: 98, loss_value: 952.4449, content_loss: 5645.9331, style_loss:   0.7757
# step: 99, loss_value: 971.4829, content_loss: 5587.8579, style_loss:   0.8254
# step: 100, loss_value: 1085.0341, content_loss: 5496.1597, style_loss:   1.0708
